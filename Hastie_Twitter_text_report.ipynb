# %%
import requests
import pandas as pd
import urllib
import json

# %%
bearer_token = pd.read_csv('Twitter-Keys.txt', sep = "\t", header = 0)

# %%
header = {'Authorization' : 'Bearer {}'.format(bearer_token['Bearer_Token'].iloc[0])}

# %%
bearer_token.keys()
# Out:
# Index(['Bearer_Token'], dtype='object')

# %%
response = requests.request("GET", url, headers = header)

# %%
endpoint_url = 'https://api.twitter.com/2/tweets/search/recent'

# %%
query = urllib.parse.quote('#halloweenkills OR @halloweenmovie lang:en')

# %%
query
# Out:
# '%23halloweenkills%20OR%20%40halloweenmovie%20lang%3Aen'

# %%
my_api_url = endpoint_url + '?query={}&tweet.fields={}'.format(query, tweet_fields)

# %%
my_api_url
# Out:
# 'https://api.twitter.com/2/tweets/search/recent?query=%23halloweenkills%20OR%20%40halloweenmovie%20lang%3Aen&tweet.fields=public_metrics,created_at,author_id,lang'

# %%
tweet_fields = 'public_metrics,created_at,author_id,lang'

# %%
expansions = 'author_id'

# %%
url = endpoint_url + '?query={}&max_results=100&tweet.fields={}'.format(query, tweet_fields)

# %%
url_expansions = endpoint_url + '?query={}&max_results=100&tweet.fields={}&expansions={}&user.fields={}'.format(query, tweet_fields, expansions, 'username')

# %%
response_1 = requests.request("GET", url_expansions, headers = header)

# %%
response_1.text
# Out:
# '{"data":[{"created_at":"2021-10-21T02:51:58.000Z","public_metrics":{"retweet_count":0,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"I have watched #halloweenkills multiple times last week and I can’t stop thinking about the ending involving @missjudygreer. Please tell me this isn’t the end of her story. She deserved so much better then a crummy defeat.","author_id":"957470323754000384","id":"1451018396041158657"},{"created_at":"2021-10-21T02:51:52.000Z","public_metrics":{"retweet_count":0,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"i feel bad for this poor man he’s getting attacked for being michael when he’s not even him #halloweenkills","author_id":"1265799422329454593","id":"1451018367993847809"},{"created_at":"2021-10-21T02:51:28.000Z","public_metrics":{"retweet_count":417,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"RT @azciscoxo: Michael Myers when they surrounded him  #HalloweenKills https://t.co/5rJXkt3uit","author_id":"1029927567338483712","id":"1451018268441985024"},{"created_at":"2021-10-21T02:51:26.000Z","public_metrics":{"retweet_count":2,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"RT @Scaretroducing: \\uD83C\\uDF83 NEW EPISODE\\uD83C\\uDF83\\n\\nShould #HalloweenKills aim higher than a pile of dead bodies?\\nDoes #Titane anoint Julia Ducournau as th…","author_id":"703921664006819840","id":"1451018258623074305"},{"created_at":"2021-10-21T02:51:20.000Z","public_metrics":{"retweet_count":201,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…","author_id":"230983228","id":"1451018233708834817"},{"created_at":"2021-10-21T02:50:47.000Z","public_metrics":{"retweet_count":1,"reply_count":0,"like_count":0,"quote_count":0},"lang":"und","text":"RT @LaydenRobinson: @BookClubEmerald @mnsb25 https://t.co/PzLLJNMoEQ #Halloween #HalloweenKills #October #Fall #Creepy #Scream #Horror","author_id":"1040939998797811712","id":"1451018096869879816"},{"created_at":"2021-10-21T02:50:47.000Z","public_metrics":{"retweet_count":22,"reply_count":0,"like_count":0,"quote_count":0},"lang":"pt","text":"RT @VivaTodorov: didático.\\n\\n#Halloween \\n#HalloweenMovie \\n#HalloweenKills https://t.co/wrs8V6FSl3","author_id":"1581712848","id":"1451018094910992384"},{"created_at":"2021-10-21T02:50:36.000Z","public_metrics":{"retweet_count":0,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"Bout to see what #halloweenkills is like \\uD83E\\uDDD0","author_id":"2941791227","id":"1451018051051270146"},{"created_at":"2021-10-21T02:50:27.000Z","public_metrics":{"retweet_count":0,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"@halloweenmovie @peacockTV Hate to say it, but #HalloweenKills was a colossal disappointment IMO. I was a faithful fan even though Michael came back to life after being beheaded (FFS) in the past. The Halloween’s should’ve ended with the last movie when Laurie prepped her house to lock him in and kill him.","author_id":"1116434731468505088","id":"1451018013231230978"},{"created_at":"2021-10-21T02:50:18.000Z","public_metrics":{"retweet_count":0,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"I laugh every time in #halloweenkills when the sheriff yells: \\"Goddamn it Brackett\\" Lol\\n@TheLostRiverDr1 @SledgeHammerHor   @KennySledge","author_id":"40956373","id":"1451017974454829061"},{"created_at":"2021-10-21T02:50:15.000Z","public_metrics":{"retweet_count":36,"reply_count":0,"like_count":0,"quote_count":0},"lang":"en","text":"RT @THR: “As the sort of face of the franchise, my job is to make sure people know I appreciate them. Every person on the crew, the actors,…","author_id":"1172933096423022594","id":"1451017960697516047"},{"created_at":"2021-10-21T02:50:08.000Z","public_metrics":{"retweet_count":11661,"reply_count":0,"like_c ...

# %%
response_1_dict = json.loads(response_1.text)

# %%
response_1_dict.keys()
# Out:
# dict_keys(['data', 'includes', 'meta'])

# %%
my_df = pd.DataFrame(response_1_dict['data'])

# %%
my_df
# Out:
#                   created_at  \
# 0   2021-10-21T02:51:58.000Z
# 1   2021-10-21T02:51:52.000Z
# 2   2021-10-21T02:51:28.000Z
# 3   2021-10-21T02:51:26.000Z
# 4   2021-10-21T02:51:20.000Z
# ..                       ...
# 95  2021-10-21T02:34:40.000Z
# 96  2021-10-21T02:34:27.000Z
# 97  2021-10-21T02:34:21.000Z
# 98  2021-10-21T02:34:20.000Z
# 99  2021-10-21T02:34:11.000Z
#
#                                        public_metrics lang  \
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 1   {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 2   {'retweet_count': 417, 'reply_count': 0, 'like...   en
# 3   {'retweet_count': 2, 'reply_count': 0, 'like_c...   en
# 4   {'retweet_count': 201, 'reply_count': 0, 'like...   en
# ..                                                ...  ...
# 95  {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 96  {'retweet_count': 445, 'reply_count': 0, 'like...   en
# 97  {'retweet_count': 0, 'reply_count': 0, 'like_c...   pt
# 98  {'retweet_count': 0, 'reply_count': 0, 'like_c...   en
# 99  {'retweet_count': 135, 'reply_count': 0, 'like...   es
#
#                                                  text            author_id  \
# 0   I have watched #halloweenkills multiple times ...   957470323754000384
# 1   i feel bad for this poor man he’s getting atta...  1265799422329454593
# 2   RT @azciscoxo: Michael Myers when they surroun...  1029927567338483712
# 3   RT @Scaretroducing: 🎃 NEW EPISODE🎃\n\nShould #...   703921664006819840
# 4   RT @halloweenmovie: A series of encounters bet...            230983228
# ..                                                ...                  ...
# 95  WHO WROTE THIS MOVIE. SO DISAPPOINTED #HALLOWE...            242491306
# 96  RT @faemothra: michael through the years #Hall...  1220223101952086023
# 97  Mesmo com a preguiça dos roteirista e caos vis...            379552090
# 98  Considering the David Gordon Green verse goes ...  1143981184252178432
# 99  RT @UniversalMX: Michael Myers sobrevivió al i...            172534065
#
#                      id
# 0   1451018396041158657
# 1   1451018367993847809
# 2   1451018268441985024
# 3   1451018258623074305
# 4   1451018233708834817
# ..                  ...
# 95  1451014042290696194
# 96  1451013985944236039
# 97  1451013960598183937
# 98  1451013958534504453
# 99  1451013918089007106
#
# [100 rows x 6 columns]

# %%
response_1_dict['meta']
# Out:
# {'newest_id': '1451018396041158657',
#  'oldest_id': '1451013918089007106',
#  'result_count': 100,
#  'next_token': 'b26v89c19zqg8o3fpdv67filgd3r83ch1cyn5xeuxcsxp'}

# %%
response_1_dict
# Out:
# {'data': [{'created_at': '2021-10-21T02:51:58.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'I have watched #halloweenkills multiple times last week and I can’t stop thinking about the ending involving @missjudygreer. Please tell me this isn’t the end of her story. She deserved so much better then a crummy defeat.',
#    'author_id': '957470323754000384',
#    'id': '1451018396041158657'},
#   {'created_at': '2021-10-21T02:51:52.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'i feel bad for this poor man he’s getting attacked for being michael when he’s not even him #halloweenkills',
#    'author_id': '1265799422329454593',
#    'id': '1451018367993847809'},
#   {'created_at': '2021-10-21T02:51:28.000Z',
#    'public_metrics': {'retweet_count': 417,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @azciscoxo: Michael Myers when they surrounded him  #HalloweenKills https://t.co/5rJXkt3uit',
#    'author_id': '1029927567338483712',
#    'id': '1451018268441985024'},
#   {'created_at': '2021-10-21T02:51:26.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @Scaretroducing: 🎃 NEW EPISODE🎃\n\nShould #HalloweenKills aim higher than a pile of dead bodies?\nDoes #Titane anoint Julia Ducournau as th…',
#    'author_id': '703921664006819840',
#    'id': '1451018258623074305'},
#   {'created_at': '2021-10-21T02:51:20.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '230983228',
#    'id': '1451018233708834817'},
#   {'created_at': '2021-10-21T02:50:47.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': 'RT @LaydenRobinson: @BookClubEmerald @mnsb25 https://t.co/PzLLJNMoEQ #Halloween #HalloweenKills #October #Fall #Creepy #Scream #Horror',
#    'author_id': '1040939998797811712',
#    'id': '1451018096869879816'},
#   {'created_at': '2021-10-21T02:50:47.000Z',
#    'public_metrics': {'retweet_count': 22,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'pt',
#    'text': 'RT @VivaTodorov: didático.\n\n#Halloween \n#HalloweenMovie \n#HalloweenKills https://t.co/wrs8V6FSl3',
#    'author_id': '1581712848',
#    'id': '1451018094910992384'},
#   {'created_at': '2021-10-21T02:50:36.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Bout to see what #halloweenkills is like 🧐',
#    'author_id': '2941791227',
#    'id': '1451018051051270146'},
#   {'created_at': '2021-10-21T02:50:27.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '@halloweenmovie @peacockTV Hate to say it, but #HalloweenKills was a colossal disappointment IMO. I was a faithful fan even though Michael came back to life after being beheaded (FFS) in the past. The Halloween’s should’ve ended with the last movie when Laurie prepped her house to lock him in and kill him.',
#    'author_id': '1116434731468505088',
#    'id': '1451018013231230978'},
#   {'created_at': '2021-10-21T02:50:18.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'I laugh every time in #halloweenkills when the sheriff yells: "Goddamn it Brackett" Lol\n@TheLostRiverDr1 @SledgeHammerHor   @KennySledge',
#    'author_id': '40956373',
#    'id': '1451017974454829061'},
#   {'created_at': '2021-10-21T02:50:15.000Z',
#    'public_metrics': {'retweet_count': 36,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @THR: “As the sort of face of the franchise, my job is to make sure people know I appreciate them. Every person on the crew, the actors,…',
#    'author_id': '1172933096423022594',
#    'id': '1451017960697516047'},
#   {'created_at': '2021-10-21T02:50:08.000Z',
#    'public_metrics': {'retweet_count': 11661,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @THR: Jamie Lee Curtis is on the red carpet of #HalloweenKills dressed as Marion Crane from #Psycho, the role played by her mother, Jane…',
#    'author_id': '1172933096423022594',
#    'id': '1451017933858250752'},
#   {'created_at': '2021-10-21T02:49:55.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @Montez2333: Yes it happening too 🤣😂🤣😂🤣 @jimmychampane @RealMMyers78 @LaurieStrodeH2O @LaurieStrode21 @halloweenmovie 🤣🤣🤣🤣🤣 https://t.co…',
#    'author_id': '168067595',
#    'id': '1451017879533592577'},
#   {'created_at': '2021-10-21T02:49:44.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'why the fuck… is no one shooting Michael Myers in the head? or decapitating him? that town has a homicidal maniac kink.. there’s no other explanation #halloweenkills',
#    'author_id': '1091202751038537728',
#    'id': '1451017831219228677'},
#   {'created_at': '2021-10-21T02:49:35.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'the cinematography in #HalloweenKills is top notch and that’s all i have to say goodbye. https://t.co/9AIxNpyj6i',
#    'author_id': '1283517736426057730',
#    'id': '1451017792929607690'},
#   {'created_at': '2021-10-21T02:49:27.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '323493560',
#    'id': '1451017759819649026'},
#   {'created_at': '2021-10-21T02:49:20.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'The crossover we needed.\nMichael Myers vs My Hero Academia.\n\n#halloween #halloweenkills #mha #MyHeroAcademia https://t.co/os4D87CyFf',
#    'author_id': '114303999',
#    'id': '1451017729666949120'},
#   {'created_at': '2021-10-21T02:49:14.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "In every #Halloween movie people run and look back at Mike like he gonna stop walking them down. Just run. It's simple. #halloweenkills #halloween2021 #HalloweenMovie https://t.co/mTHWsUUswR",
#    'author_id': '321742924',
#    'id': '1451017704656232453'},
#   {'created_at': '2021-10-21T02:49:10.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "It's our Halloween Special on Terror In The Aisles, and we talk all kinds of spooky talk!  Scotty Slasher and Movie John talk about Halloween Kills, Chucky Tv Series, Midnight Mass, and more!\n#TerrorInTheAisles #HalloweenKills #HorrorPodcast #ChuckyTV \nhttps://t.co/Yfdv5BhK7L",
#    'author_id': '1444496205325688836',
#    'id': '1451017689422565377'},
#   {'created_at': '2021-10-21T02:48:48.000Z',
#    'public_metrics': {'retweet_count': 3,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @WeWatchedAMovie: Late night video? I think we will! We go through and talk about every survivor of #HalloweenKills and what they could…',
#    'author_id': '1397060586794405891',
#    'id': '1451017596069826563'},
#   {'created_at': '2021-10-21T02:48:38.000Z',
#    'public_metrics': {'retweet_count': 114,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @getFANDOM: #HalloweenKills director calls Laurie’s granddaughter, Allyson the ‘core’ of the story in ‘Halloween Ends’\n\nThe final film i…',
#    'author_id': '1359599972610580481',
#    'id': '1451017557612269571'},
#   {'created_at': '2021-10-21T02:48:36.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '#HalloweenKills is the Last Jedi of the Michael Myers saga: in the name of trying to create twists and surprises, they tear down a good portion of what its predecessor built. https://t.co/hEqCcVM9Qt',
#    'author_id': '202394728',
#    'id': '1451017548993081346'},
#   {'created_at': '2021-10-21T02:47:41.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Yes it happening too 🤣😂🤣😂🤣 @jimmychampane @RealMMyers78 @LaurieStrodeH2O @LaurieStrode21 @halloweenmovie 🤣🤣🤣🤣🤣 https://t.co/VvEI96Ffhh',
#    'author_id': '168067595',
#    'id': '1451017318021140487'},
#   {'created_at': '2021-10-21T02:47:33.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "Anniversary dinner is Thai food delivered while watching @halloweenmovie #HalloweenKills. We're so romantic. 🤣 https://t.co/aVLW7BJqqm",
#    'author_id': '718713474',
#    'id': '1451017282361053185'},
#   {'created_at': '2021-10-21T02:47:33.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Big John?? Yes Little John?? 😂😂this movie is too much #halloweenkills #MichaelMyers',
#    'author_id': '3094401781',
#    'id': '1451017281945829376'},
#   {'created_at': '2021-10-21T02:47:32.000Z',
#    'public_metrics': {'retweet_count': 58,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': 'RT @ScreamWithRCS: #HalloweenKills https://t.co/2vYt9NV1bA',
#    'author_id': '724373114',
#    'id': '1451017277042839557'},
#   {'created_at': '2021-10-21T02:47:31.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '#Halloweenkills was fucking trash 😭 I want my time back',
#    'author_id': '719361766250135553',
#    'id': '1451017275876777987'},
#   {'created_at': '2021-10-21T02:47:10.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Okay #HalloweenKills was 🚮',
#    'author_id': '2229088568',
#    'id': '1451017185053364232'},
#   {'created_at': '2021-10-21T02:47:07.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Big John and Little John deserved better #HalloweenKills',
#    'author_id': '3754093634',
#    'id': '1451017175163187200'},
#   {'created_at': '2021-10-21T02:46:46.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Miguel Myers 🔪 \n#halloweenkills',
#    'author_id': '130241263',
#    'id': '1451017086264913920'},
#   {'created_at': '2021-10-21T02:46:43.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Silly white kids just was playing hide and seek with Michael Myers like he was they friend lmao. #Halloween #halloween2021 #HalloweenMovie #halloweenkills https://t.co/XpB1itAWf3',
#    'author_id': '321742924',
#    'id': '1451017073505800194'},
#   {'created_at': '2021-10-21T02:46:41.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "@halloweenmovie @thebandGHOST This song is so damn good. I've listened to it at least a hundred times. Ghost knocked it out of the park as usual",
#    'author_id': '287450113',
#    'id': '1451017065846824961'},
#   {'created_at': '2021-10-21T02:46:28.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '2959666049',
#    'id': '1451017011199361024'},
#   {'created_at': '2021-10-21T02:46:12.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '770815828266659840',
#    'id': '1451016941133451272'},
#   {'created_at': '2021-10-21T02:46:02.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': '#HalloweenKills was 🤌🎃🔪 https://t.co/TwfNfxFOaU',
#    'author_id': '22809979',
#    'id': '1451016899974811652'},
#   {'created_at': '2021-10-21T02:45:23.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '@halloweenmovie had some ridiculous killing scenes 💀💀💀',
#    'author_id': '96206212',
#    'id': '1451016739018493953'},
#   {'created_at': '2021-10-21T02:45:13.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Week of release I saw someone say #HalloweenKills was gonna be The Last Jedi of the franchise &amp; of slashers in how people will react to it one way or the other, and they weren’t wrong. https://t.co/IxYeI9ckok',
#    'author_id': '717472811955183618',
#    'id': '1451016696710500356'},
#   {'created_at': '2021-10-21T02:45:01.000Z',
#    'public_metrics': {'retweet_count': 149,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @GeekVibesNews: Enter for a chance to win a #HalloweenKills\xa0\xa0 prize pack including T-Shirt and full size poster \n\nFollow @GeekVibesNatio…',
#    'author_id': '22542548',
#    'id': '1451016646957674502'},
#   {'created_at': '2021-10-21T02:44:47.000Z',
#    'public_metrics': {'retweet_count': 52,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @kinky_horror: After (finally!) getting to watch #HalloweenKills, here’s my super in-depth review: https://t.co/U9jYoOF4S5',
#    'author_id': '105556328',
#    'id': '1451016587272617986'},
#   {'created_at': '2021-10-21T02:44:08.000Z',
#    'public_metrics': {'retweet_count': 3,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'es',
#    'text': 'RT @bloody_erick: ¿Creían que me iba a quedar con las ganas de comentar #HalloweenKills? Pues acá tienen un nuevo video para hablar de la r…',
#    'author_id': '1263650122644312066',
#    'id': '1451016423959109640'},
#   {'created_at': '2021-10-21T02:43:57.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'The unholy house of bloom tried to stop me, but now it happens. Watch me shit on this one live. @halloweenmovie @blumhouse @HorrorRetweet @horror_retweets @Horror_Retweet @PromoteHorror @PromotionHorror @HorrorPromotion @jamieleecurtis @BustaRhymes @Halloweenmovies @FANGORIA https://t.co/jbMBUj13U8',
#    'author_id': '795838640064790528',
#    'id': '1451016374910951429'},
#   {'created_at': '2021-10-21T02:43:50.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @BORReport: Halloween Kills grossed $2.74M on Tuesday (from 3,705 locations).  Total gross stands at $54.87M.\n\n#HalloweenKills  #BoxOffi…',
#    'author_id': '736710115',
#    'id': '1451016348495228933'},
#   {'created_at': '2021-10-21T02:43:50.000Z',
#    'public_metrics': {'retweet_count': 12,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'es',
#    'text': 'RT @TheVMAltamirano: Michael Myers cuando todo el pueblo lo acorrala en #HalloweenKills https://t.co/2cJVfgI8q8',
#    'author_id': '93246590',
#    'id': '1451016347295617025'},
#   {'created_at': '2021-10-21T02:43:50.000Z',
#    'public_metrics': {'retweet_count': 84,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: The legacy of Laurie Strode continues. See @jamieleecurtis in #HalloweenKills - Now In Theaters &amp; Streaming Only on @pe…',
#    'author_id': '121334757',
#    'id': '1451016345752117254'},
#   {'created_at': '2021-10-21T02:43:31.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @HalloweenDaily: TONIGHT is the #HuntersMoon!! You know what to do. CRANK IT UP!!! \nhttps://t.co/A3yXyMA4VA \n🤘🎃🤘 #HalloweenKills #Michae…',
#    'author_id': '380735885',
#    'id': '1451016267293360133'},
#   {'created_at': '2021-10-21T02:43:14.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'I just want everyone to know that I watched #HalloweenKills \n\nNow, I’ll patiently wait for Oct 2022 for #HalloweenEnds. \n\nGotta let the story play out. \n\nThe callbacks were cool, ok.',
#    'author_id': '25573769',
#    'id': '1451016196288090119'},
#   {'created_at': '2021-10-21T02:43:11.000Z',
#    'public_metrics': {'retweet_count': 17,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'fr',
#    'text': 'RT @sueltosencaba: Tarde de cine 🍿 #HalloweenKills https://t.co/UBs1cJHrMX',
#    'author_id': '978845127610372097',
#    'id': '1451016182811693062'},
#   {'created_at': '2021-10-21T02:43:00.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'i thought #halloweenkills was gone steal the halloween thunder but really it’s #CHUCKYTVSERIES',
#    'author_id': '1342940809868488709',
#    'id': '1451016138016575488'},
#   {'created_at': '2021-10-21T02:42:57.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Watching #HalloweenKills with the bros! Celebrating @mAdd_p0pc0rN cumpleaños 🎂 #MichaelMyers #HalloweenKills 🔪 🎃 https://t.co/upmtwnaJeQ',
#    'author_id': '360081427',
#    'id': '1451016123764264964'},
#   {'created_at': '2021-10-21T02:42:53.000Z',
#    'public_metrics': {'retweet_count': 5,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': 'RT @SourceHalloween: #halloweenkills 🔥🔥🔥 https://t.co/LVZAiBFZNW',
#    'author_id': '1137888739076841474',
#    'id': '1451016109914742787'},
#   {'created_at': '2021-10-21T02:42:46.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '@transmissionwax @SacredBones @halloweenmovie Hello, I never received a confirmation email for this back when I ordered it but the money has definitely been taken from my account. Really hope it arrives soon!',
#    'author_id': '1130978566286524417',
#    'id': '1451016080575631361'},
#   {'created_at': '2021-10-21T02:42:41.000Z',
#    'public_metrics': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @legit_writers1: We ensure #A+ in your 🌏 🌔 \n #ESSAYS \n #DataScience   \n #MATHS\n #ACCOUNTS\n #FINANCE\n #STATS\n #WRITING \n #RESEARCH\n #NURS…',
#    'author_id': '1364497572509880322',
#    'id': '1451016057712414726'},
#   {'created_at': '2021-10-21T02:42:30.000Z',
#    'public_metrics': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @legit_writers1: We ensure #A+ in your 🌏 🌔 \n #ESSAYS \n #DataScience   \n #MATHS\n #ACCOUNTS\n #FINANCE\n #STATS\n #WRITING \n #RESEARCH\n #NURS…',
#    'author_id': '1127829883013361665',
#    'id': '1451016010035777539'},
#   {'created_at': '2021-10-21T02:42:29.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '1137888739076841474',
#    'id': '1451016008022515712'},
#   {'created_at': '2021-10-21T02:42:29.000Z',
#    'public_metrics': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @legit_writers1: We ensure #A+ in your 🌏 🌔 \n #ESSAYS \n #DataScience   \n #MATHS\n #ACCOUNTS\n #FINANCE\n #STATS\n #WRITING \n #RESEARCH\n #NURS…',
#    'author_id': '1403020350871400451',
#    'id': '1451016006684618752'},
#   {'created_at': '2021-10-21T02:42:25.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'The Haddonfield Star Trek Fan Club: \n"The radio says William Shatner\'s on a killing spree here in town! We\'re the only ones who can stop him!"\n@Halloweenmovies #HalloweenKills @jamieleecurtis @StarTrek',
#    'author_id': '1438910001372811267',
#    'id': '1451015991274602499'},
#   {'created_at': '2021-10-21T02:42:05.000Z',
#    'public_metrics': {'retweet_count': 149,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @GeekVibesNews: Enter for a chance to win a #HalloweenKills\xa0\xa0 prize pack including T-Shirt and full size poster \n\nFollow @GeekVibesNatio…',
#    'author_id': '1218710531625963520',
#    'id': '1451015906654572547'},
#   {'created_at': '2021-10-21T02:41:44.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '4884818511',
#    'id': '1451015818100236288'},
#   {'created_at': '2021-10-21T02:41:43.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Okay…. The park scene in #HalloweenKills is perfection. I don’t get the hate, this movie slaps and I’m not even a fan of the franchise. #MutantFam #HorrorFam #MichaelMyers',
#    'author_id': '87274303',
#    'id': '1451015815776636929'},
#   {'created_at': '2021-10-21T02:41:39.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '71886420',
#    'id': '1451015798391287808'},
#   {'created_at': '2021-10-21T02:41:38.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '932024506360532993',
#    'id': '1451015794280763395'},
#   {'created_at': '2021-10-21T02:41:36.000Z',
#    'public_metrics': {'retweet_count': 78,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @faemothra: the shape #MichaelMyers #halloweenkills https://t.co/eF8QMEfTvy',
#    'author_id': '2420825407',
#    'id': '1451015785615265793'},
#   {'created_at': '2021-10-21T02:41:20.000Z',
#    'public_metrics': {'retweet_count': 149,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @GeekVibesNews: Enter for a chance to win a #HalloweenKills\xa0\xa0 prize pack including T-Shirt and full size poster \n\nFollow @GeekVibesNatio…',
#    'author_id': '1131465523403747328',
#    'id': '1451015718267355137'},
#   {'created_at': '2021-10-21T02:41:16.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '1176611943240609796',
#    'id': '1451015702417186816'},
#   {'created_at': '2021-10-21T02:41:13.000Z',
#    'public_metrics': {'retweet_count': 30,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: @DiscussingFilm This isn’t going to end well for you.',
#    'author_id': '1238416427562029057',
#    'id': '1451015687372169222'},
#   {'created_at': '2021-10-21T02:41:02.000Z',
#    'public_metrics': {'retweet_count': 24,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'de',
#    'text': 'RT @WadeHalloween4: Halloween kills Mob Vs Michael - Michael kills mob\n#Halloweenverse #Halloweenkills https://t.co/B7zBAGNfv8',
#    'author_id': '902012656260833280',
#    'id': '1451015643872911360'},
#   {'created_at': '2021-10-21T02:40:45.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '1447579936370331652',
#    'id': '1451015572838289410'},
#   {'created_at': '2021-10-21T02:40:42.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '1380701380818571267',
#    'id': '1451015558481080323'},
#   {'created_at': '2021-10-21T02:40:40.000Z',
#    'public_metrics': {'retweet_count': 52,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @kinky_horror: After (finally!) getting to watch #HalloweenKills, here’s my super in-depth review: https://t.co/U9jYoOF4S5',
#    'author_id': '500181391',
#    'id': '1451015551615213571'},
#   {'created_at': '2021-10-21T02:40:07.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '#HalloweenKills is the Quantum of Solace of the franchise. Polarizing and brutal.',
#    'author_id': '1329018333979500545',
#    'id': '1451015413672787975'},
#   {'created_at': '2021-10-21T02:39:56.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "Just finished Halloween Kills (@halloweenmovie) on @peacockTV ! \n\nSpoiler-free alert: it's brutal to watch. 👹🎃",
#    'author_id': '15076477',
#    'id': '1451015364855222273'},
#   {'created_at': '2021-10-21T02:39:46.000Z',
#    'public_metrics': {'retweet_count': 329,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "RT @halloweenmovie: It's time to face your fear. Michael Myers is coming home. #HalloweenKills is NOW In Theaters &amp; Streaming Only on @peac…",
#    'author_id': '165258426',
#    'id': '1451015324787216388'},
#   {'created_at': '2021-10-21T02:39:41.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': '@halloweenmovie @jamieleecurtis @peacockTV Hoping Danielle Harris will be in the next one',
#    'author_id': '1321519192894590976',
#    'id': '1451015303933145088'},
#   {'created_at': '2021-10-21T02:39:40.000Z',
#    'public_metrics': {'retweet_count': 18,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': 'RT @DrSamLoomis78: #HalloweenKills #Horror #Halloween https://t.co/8bF317JbCA',
#    'author_id': '1309577579305693184',
#    'id': '1451015299348586501'},
#   {'created_at': '2021-10-21T02:39:29.000Z',
#    'public_metrics': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @legit_writers1: We ensure #A+ in your 🌏 🌔 \n #ESSAYS \n #DataScience   \n #MATHS\n #ACCOUNTS\n #FINANCE\n #STATS\n #WRITING \n #RESEARCH\n #NURS…',
#    'author_id': '1260015280048222208',
#    'id': '1451015253555388417'},
#   {'created_at': '2021-10-21T02:39:24.000Z',
#    'public_metrics': {'retweet_count': 52,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @kinky_horror: After (finally!) getting to watch #HalloweenKills, here’s my super in-depth review: https://t.co/U9jYoOF4S5',
#    'author_id': '166080774',
#    'id': '1451015232193658881'},
#   {'created_at': '2021-10-21T02:38:57.000Z',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @Filmlosophy101: The Filmlosophers continue their celebration of the month of spooktacular with a chat over the latest horror offering o…',
#    'author_id': '282968815',
#    'id': '1451015118158925824'},
#   {'created_at': '2021-10-21T02:38:49.000Z',
#    'public_metrics': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @legit_writers1: We ensure #A+ in your 🌏 🌔 \n #ESSAYS \n #DataScience   \n #MATHS\n #ACCOUNTS\n #FINANCE\n #STATS\n #WRITING \n #RESEARCH\n #NURS…',
#    'author_id': '1272433034159992833',
#    'id': '1451015087062405121'},
#   {'created_at': '2021-10-21T02:38:30.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'de',
#    'text': 'Man erfindet einen Grund, warum Michael Myers so ist wie er ist. Nur um am Ende zu sagen, ach scheiß drauf, er ist das pure Böse.\nIm letzten Teil dann bitte im Rollstuhl.\n#HalloweenMovie #halloweenkills',
#    'author_id': '1449209200601669637',
#    'id': '1451015007102189569'},
#   {'created_at': '2021-10-21T02:38:29.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': '☠️☠️☠️ #HalloweenKills https://t.co/xVimQRBdJQ',
#    'author_id': '259782603',
#    'id': '1451015001964228609'},
#   {'created_at': '2021-10-21T02:37:42.000Z',
#    'public_metrics': {'retweet_count': 19,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @SoWizardPodcast: NEW #PODCAST! This week we are joined by @ODParlayHour to talk all the #DCFanDome news and review #HalloweenKills! Evi…',
#    'author_id': '1336883884059975681',
#    'id': '1451014804831981575'},
#   {'created_at': '2021-10-21T02:37:32.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '815717103923826689',
#    'id': '1451014761286672384'},
#   {'created_at': '2021-10-21T02:37:15.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': '#Halloween #halloween2018 #halloweenkills #MichaelMyers #jamieleecurtis #davidgordongreen #TheShape #johncarpenter #2021 #horror #horrormovie #hadfonfield #lauriestrode https://t.co/0BB4AzxpMb',
#    'author_id': '1194884336',
#    'id': '1451014690075721735'},
#   {'created_at': '2021-10-21T02:37:11.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 2,
#     'like_count': 3,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'I just rewatched #halloweenkills and tried to keep count of how many times “Evil dies tonight” was said. I got to 21.',
#    'author_id': '1262405774648770561',
#    'id': '1451014675857092608'},
#   {'created_at': '2021-10-21T02:36:37.000Z',
#    'public_metrics': {'retweet_count': 38,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @SourceHalloween: The shape with blood on his mask 🩸 #halloweenkills https://t.co/TdGsNbeYZn',
#    'author_id': '471712767',
#    'id': '1451014533091364874'},
#   {'created_at': '2021-10-21T02:36:19.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'well @halloweenmovie was blah! Like fuck man why did it have to be so predictable!',
#    'author_id': '1012235956177514496',
#    'id': '1451014453907099648'},
#   {'created_at': '2021-10-21T02:35:36.000Z',
#    'public_metrics': {'retweet_count': 58,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'und',
#    'text': 'RT @ScreamWithRCS: #HalloweenKills https://t.co/2vYt9NV1bA',
#    'author_id': '2261047882',
#    'id': '1451014274751647748'},
#   {'created_at': '2021-10-21T02:35:30.000Z',
#    'public_metrics': {'retweet_count': 193,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'ca',
#    'text': "RT @horrorlosers: #HalloweenKills dentro del especial de SNOOPY 'It's The Great Pumpkin, Charlie Brown!' (1966) es el crossover más ambicio…",
#    'author_id': '878075288625840128',
#    'id': '1451014250613415936'},
#   {'created_at': '2021-10-21T02:35:30.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Thread. I finally watched @halloweenmovie, and suddenly remembered that I pitched a HALLOWEEN reboot to @DimensionFilms in 2012. This was post-Rob Zombie, and they wanted to capitalize on the "found footage" craze. I figured, why not give it a shot? I\'m a huge fan of the original',
#    'author_id': '1600983402',
#    'id': '1451014249652924416'},
#   {'created_at': '2021-10-21T02:35:13.000Z',
#    'public_metrics': {'retweet_count': 2,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @ChuckXL: Is there a McDonalds / #HalloweenKills promotion I’m not aware of? https://t.co/JKOejDI5m6',
#    'author_id': '14218312',
#    'id': '1451014180249784321'},
#   {'created_at': '2021-10-21T02:35:08.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': "I praise Halloween Kills but I will say the biggest misstep was Laurie completely no-selling finding out that, for the last 40 years, Michael hasn't given her a 2nd thought. it's not about her. the film completely blows past this. thoughts? #halloweenkills",
#    'author_id': '19652932',
#    'id': '1451014159785762817'},
#   {'created_at': '2021-10-21T02:35:08.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Check out 🎃 Michael Myers, Chucky &amp; Pennywise Gemmy 10” Animated Plush Waddler Set-NWT 🎃 https://t.co/9pzEIZdPbJ #MichaelMyers\xa0\xa0\xa0 #It #Pennywise #Chucky\xa0\xa0\xa0 #HalloweenKills\xa0\xa0 #Waddler #Gemmy #Waddlers #ChuckyShow\xa0\xa0\xa0 #Halloween #HalloweenDecor #HalloweenWaddlers https://t.co/UmUNNkLWZB',
#    'author_id': '1169669641',
#    'id': '1451014159378915334'},
#   {'created_at': '2021-10-21T02:35:07.000Z',
#    'public_metrics': {'retweet_count': 201,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @halloweenmovie: A series of encounters between creative forces from various worlds of sound &amp; vision has resulted in “Hunter’s Moon,” t…',
#    'author_id': '985649599070093319',
#    'id': '1451014155213762560'},
#   {'created_at': '2021-10-21T02:34:55.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Check out 🎃 Michael Myers, Chucky &amp; Pennywise Gemmy 10” Animated Plush Waddler Set-NWT 🎃 https://t.co/9pzEIZdPbJ #MichaelMyers\xa0\xa0\xa0 #It #Pennywise #Chucky\xa0\xa0\xa0 #HalloweenKills\xa0\xa0 #Waddler #Gemmy #Waddlers #ChuckyShow\xa0\xa0\xa0 #Halloween #HalloweenDecor #HalloweenWaddlers',
#    'author_id': '1169669641',
#    'id': '1451014104831889412'},
#   {'created_at': '2021-10-21T02:34:48.000Z',
#    'public_metrics': {'retweet_count': 12,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @Norville1982: People can say what they like, I bloody enjoyed #HalloweenKills bring on #HalloweenEnds next year! https://t.co/uhmMGMNROd',
#    'author_id': '20223352',
#    'id': '1451014076172324866'},
#   {'created_at': '2021-10-21T02:34:40.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'WHO WROTE THIS MOVIE. SO DISAPPOINTED #HALLOWEENKILLS',
#    'author_id': '242491306',
#    'id': '1451014042290696194'},
#   {'created_at': '2021-10-21T02:34:27.000Z',
#    'public_metrics': {'retweet_count': 445,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'RT @faemothra: michael through the years #HalloweenKills https://t.co/TsNTdVRI7h',
#    'author_id': '1220223101952086023',
#    'id': '1451013985944236039'},
#   {'created_at': '2021-10-21T02:34:21.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'pt',
#    'text': 'Mesmo com a preguiça dos roteirista e caos visual do apresentado em algumas cenas, eu gostei do filme. Só gostaria de ver Jamie Lee Curtis em "ação" #HalloweenKills #HalloweenMovie',
#    'author_id': '379552090',
#    'id': '1451013960598183937'},
#   {'created_at': '2021-10-21T02:34:20.000Z',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'text': 'Considering the David Gordon Green verse goes out of its way to say that Halloween II is NOT canon, there sure is A LOT of connective tissue in #HalloweenKills.\n\nBTW I love #HalloweenKills - top 3 film of 2021 for me. https://t.co/fWqzZInNu6',
#    'author_id': '1143981184252178432',
#    'id': '1451013958534504453'},
#   {'created_at': '2021-10-21T02:34:11.000Z',
#    'public_metrics': {'retweet_count': 135,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'es',
#    'text': 'RT @UniversalMX: Michael Myers sobrevivió al incendio, pero esta vez las Strode no están solas. Vive un nuevo capítulo de este clásico del…',
#    'author_id': '172534065',
#    'id': '1451013918089007106'}],
#  'includes': {'users': [{'id': '957470323754000384',
#     'name': 'Dakota',
#     'username': 'KodaFlixster'},
#    {'id': '1265799422329454593', 'name': 'jay 🕷', 'username': 'yourightvinyl'},
#    {'id': '1029927567338483712', 'name': 'Lisbethh .', 'username': 'lovoxxli'},
#    {'id': '703921664006819840',
#     'name': 'The Horror Returns',
#     'username': 'horror_returns'},
#    {'id': '230983228', 'name': 'kesetaraan genjer', 'username': 'diupayakan'},
#    {'id': '1040939998797811712',
#     'name': 'Emerald Book Club',
#     'username': 'BookClubEmerald'},
#    {'id': '1581712848',
#     'name': 'YuliyaInopinaPR 😍✌🌺😎🌵😝👉👉👉',
#     'username': 'YuliyaInopinaPR'},
#    {'id': '2941791227', 'name': 'youKNOWme.🖤', 'username': 'La_Naenaeeee'},
#    {'id': '1116434731468505088', 'name': 'Pam', 'username': 'Pamela53258082'},
#    {'id': '40956373',
#     'name': 'John Walter Seip',
#     'username': 'johnwalterseip'},
#    {'id': '1172933096423022594', 'name': 'dani⁷☻', 'username': 'g0ttabejoon'},
#    {'id': '168067595',
#     'name': 'Ⓜ️🅾️nTEZ D🔱🅰️yne®️™️',
#     'username': 'Montez2333'},
#    {'id': '1091202751038537728', 'name': 'Dal🥭', 'username': 'heydalface'},
#    {'id': '1283517736426057730',
#     'name': 'tyler🎃',
#     'username': 'halloweenfan93'},
#    {'id': '323493560',
#     'name': '💀 The Horror Guru 💀',
#     'username': 'TheHorrorGuru'},
#    {'id': '114303999', 'name': 'David Kang', 'username': 'DKANG0316'},
#    {'id': '321742924', 'name': 'Jerz', 'username': 'JerzDaReaper'},
#    {'id': '1444496205325688836',
#     'name': 'Terror In The Aisles',
#     'username': 'TerrorAislesPod'},
#    {'id': '1397060586794405891',
#     'name': "Brian's Nightmare",
#     'username': 'WatchedLife'},
#    {'id': '1359599972610580481', 'name': 'Nicko', 'username': 'Nicko9789'},
#    {'id': '202394728',
#     'name': 'Geoff Magliocchetti',
#     'username': 'GeoffJMags'},
#    {'id': '718713474', 'name': 'Sheryl 👧🏻🌎', 'username': 'girlvsplanet'},
#    {'id': '3094401781',
#     'name': 'Lisa 💋RaiderPrincess🖤☠️',
#     'username': 'r8rprincess408'},
#    {'id': '724373114', 'name': 'Elijah 🎃', 'username': 'EliKirtos'},
#    {'id': '719361766250135553', 'name': 'Sᕼᗩ', 'username': '401sha'},
#    {'id': '2229088568', 'name': 'Nirvana', 'username': 'nirvanadavi'},
#    {'id': '3754093634',
#     'name': '🎃 Spooky Friend A 🎃',
#     'username': 'TheBasiIisk'},
#    {'id': '130241263',
#     'name': '👻 maria carrasco 🎃',
#     'username': 'macarrasco_'},
#    {'id': '287450113', 'name': 'Lion', 'username': 'LionHardt544'},
#    {'id': '2959666049', 'name': 'Razors Edge', 'username': 'razorsedge588'},
#    {'id': '770815828266659840',
#     'name': 'Arthur Morgan',
#     'username': 'ArthurZG24'},
#    {'id': '22809979', 'name': 'Art.', 'username': 'timmymtl'},
#    {'id': '96206212', 'name': 'Taron', 'username': 'Kingofthemind93'},
#    {'id': '717472811955183618',
#     'name': 'Tyler Freshcorn',
#     'username': 'tyler_freshcorn'},
#    {'id': '22542548', 'name': 'Becky', 'username': 'bearyfunscrap'},
#    {'id': '105556328',
#     'name': 'Music Godz Radio',
#     'username': 'musicgodzradio'},
#    {'id': '1263650122644312066', 'name': 'Dazer', 'username': 'mustardazer13'},
#    {'id': '795838640064790528',
#     'name': 'Daniel Schein',
#     'username': 'fleshwounddan'},
#    {'id': '736710115', 'name': 'Austin Louis', 'username': 'AustinLouis5'},
#    {'id': '93246590', 'name': 'Mr. Random', 'username': 'Danncz'},
#    {'id': '121334757', 'name': 'Jesus Myers 🔪🎃', 'username': 'ChuyRomanov'},
#    {'id': '380735885', 'name': 'Serpent6', 'username': 'Serpent6Serpent'},
#    {'id': '25573769', 'name': 'Jim Sorrells', 'username': 'JamesESorrells'},
#    {'id': '978845127610372097',
#     'name': 'Franco',
#     'username': 'Fr4ncq60mez360'},
#    {'id': '1342940809868488709',
#     'name': 'Coco Butter ♐️',
#     'username': 'Realcodaqueen'},
#    {'id': '360081427', 'name': 'Jesus Jr', 'username': 'CaliGuy_85'},
#    {'id': '1137888739076841474',
#     'name': 'Antonio 🤙🏼',
#     'username': 'antrrey94'},
#    {'id': '1130978566286524417',
#     'name': 'flop era 🏳️\u200d🌈',
#     'username': 'rome_786'},
#    {'id': '1364497572509880322', 'name': 'Bills Bot', 'username': 'Bills_Bot'},
#    {'id': '1127829883013361665', 'name': 'xael bot', 'username': 'xaelbot'},
#    {'id': '1403020350871400451', 'name': 'Lunr', 'username': 'botfordev'},
#    {'id': '1438910001372811267',
#     'name': 'Jake Stratton',
#     'username': 'JStrattonwrites'},
#    {'id': '1218710531625963520',
#     'name': 'Vivian S',
#     'username': 'StaikosVivian'},
#    {'id': '4884818511',
#     'name': 'Vampire Queen',
#     'username': 'VampiricQueen66'},
#    {'id': '87274303', 'name': 'Kevy Bear', 'username': 'Blueeyeddevil72'},
#    {'id': '71886420', 'name': 'Karon Aeefer', 'username': 'Mufan45'},
#    {'id': '932024506360532993',
#     'name': '𝑀𝑎𝑐𝑠𝑖𝑡𝑜 ₜₕₑ ᵦₒₒgᵢₑ ₘₐₙ 🐀🎃🧛🏽\u200d♂️',
#     'username': 'MaxYael625'},
#    {'id': '2420825407',
#     'name': "teagan (spooky)⁽' ᵛ ' ⁾",
#     'username': 'amoonpotion'},
#    {'id': '1131465523403747328',
#     'name': 'HOLA a.k.a HI',
#     'username': 'jumbojaxncdylax'},
#    {'id': '1176611943240609796',
#     'name': 'GHOST EN ESPAÑOL',
#     'username': 'Ghostenespanol1'},
#    {'id': '1238416427562029057',
#     'name': 'Patricia DeWitt',
#     'username': 'CreatorOfAliens'},
#    {'id': '902012656260833280', 'name': 'Shark', 'username': 'Shark50561456'},
#    {'id': '1447579936370331652', 'name': '𝑣𝑒𝑥', 'username': 'ghoulishvex'},
#    {'id': '1380701380818571267',
#     'name': '🎃Co-Founder, Boogeyman Believers of Haddonfield🎃',
#     'username': 'PumpkinWitch6'},
#    {'id': '500181391', 'name': 'Maxwell', 'username': 'SEgeek07'},
#    {'id': '1329018333979500545',
#     'name': 'Trish the Water Spirit',
#     'username': 'Ozymandiyaas'},
#    {'id': '15076477', 'name': 'Long Tran', 'username': 'longttran'},
#    {'id': '165258426',
#     'name': 'David Martinez',
#     'username': 'davidmartinezfl'},
#    {'id': '1321519192894590976',
#     'name': 'Justus',
#     'username': 'Justus13549590'},
#    {'id': '1309577579305693184',
#     'name': 'Marie Sloane669',
#     'username': 'sloane666'},
#    {'id': '1260015280048222208', 'name': 'BOT Kitty 🐈', 'username': 'BotRaj1'},
#    {'id': '166080774', 'name': 'Count Duckula', 'username': '_Duckman_'},
#    {'id': '282968815',
#     'name': 'Filmlosopher Eddie!',
#     'username': 'FilmlosopherEdd'},
#    {'id': '1272433034159992833',
#     'name': 'To The TOP!',
#     'username': 'to_the_top_bot'},
#    {'id': '1449209200601669637',
#     'name': 'WhoIsLevery',
#     'username': 'whoislevery'},
#    {'id': '259782603', 'name': 'i am ArnDizzle', 'username': 'Arndiddy23'},
#    {'id': '1336883884059975681',
#     'name': 'Game For A Movie Podcast',
#     'username': 'GameForAMovieP1'},
#    {'id': '815717103923826689',
#     'name': 'Josh Chetney',
#     'username': 'JoshChetney'},
#    {'id': '1194884336',
#     'name': 'Brandon Azaria London',
#     'username': 'BrandonLondon59'},
#    {'id': '1262405774648770561',
#     'name': 'Horror Movie Stills',
#     'username': 'horrorstills'},
#    {'id': '471712767',
#     'name': "Andy Muad'Dib Draper",
#     'username': 'AndyMuaddib87'},
#    {'id': '1012235956177514496', 'name': 'Mitch', 'username': 'MitchumTX'},
#    {'id': '2261047882', 'name': 'Raven 👻', 'username': 'RavenGillians'},
#    {'id': '878075288625840128',
#     'name': 'Yeya Yeah Yeah',
#     'username': 'ghesr0ck'},
#    {'id': '1600983402', 'name': 'Brendan Deneen', 'username': 'BrendanDeneen'},
#    {'id': '14218312', 'name': 'Count Chuckula 🎃', 'username': 'ChuckXL'},
#    {'id': '19652932',
#     'name': 'Hey, Lonnie! Get Your ASS Away From There!',
#     'username': 'NickyJames'},
#    {'id': '1169669641', 'name': 'Danny York', 'username': 'dannyamy10'},
#    {'id': '985649599070093319',
#     'name': 'RedRadburn🖤s👻',
#     'username': 'RedRadburn'},
#    {'id': '20223352',
#     'name': '🎃 Matt Haddonfield 🔪',
#     'username': '_Monkey_Boy_'},
#    {'id': '242491306', 'name': 'Jer', 'username': 'jerry_joell'},
#    {'id': '1220223101952086023',
#     'name': 'jaime | wwdits era',
#     'username': 'rosesravage'},
#    {'id': '379552090',
#     'name': 'Claudio Gonzaga',
#     'username': 'claudio_psciano'},
#    {'id': '1143981184252178432',
#     'name': 'Ian Grimm',
#     'username': 'sideshadow99'},
#    {'id': '172534065',
#     'name': 'Juan Antonio Campos',
#     'username': 'JACamposH'}]},
#  'meta': {'newest_id': '1451018396041158657',
#   'oldest_id': '1451013918089007106',
#   'result_count': 100,
#   'next_token': 'b26v89c19zqg8o3fpdv67filgd3r83ch1cyn5xeuxcsxp'}}

# %%
user_info = pd.DataFrame(response_1_dict['includes']['users'])

# %%
my_df['name'] = user_info['name']
my_df['username'] = user_info['username']
my_df
# Out:
#                                        public_metrics            author_id  \
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...            196348989
# 1   {'retweet_count': 4, 'reply_count': 0, 'like_c...  1421261552422895618
# 2   {'retweet_count': 214, 'reply_count': 0, 'like...  1294531407352651777
# 3   {'retweet_count': 38, 'reply_count': 0, 'like_...  1448328941270454287
# 4   {'retweet_count': 153, 'reply_count': 0, 'like...  1090776054506053632
# ..                                                ...                  ...
# 95  {'retweet_count': 0, 'reply_count': 2, 'like_c...           1021502280
# 96  {'retweet_count': 143, 'reply_count': 0, 'like...  1150423273546502144
# 97  {'retweet_count': 214, 'reply_count': 0, 'like...            441134548
# 98  {'retweet_count': 214, 'reply_count': 0, 'like...  1376283615986847748
# 99  {'retweet_count': 214, 'reply_count': 0, 'like...  1249826534501896193
#
#                      id                created_at  \
# 0   1451013861532971017  2021-10-21T02:33:57.000Z
# 1   1451013830763597827  2021-10-21T02:33:50.000Z
# 2   1451013830432149504  2021-10-21T02:33:50.000Z
# 3   1451013824560173056  2021-10-21T02:33:48.000Z
# 4   1451013813365624832  2021-10-21T02:33:46.000Z
# ..                  ...                       ...
# 95  1451009486538293250  2021-10-21T02:16:34.000Z
# 96  1451009421929115653  2021-10-21T02:16:19.000Z
# 97  1451009367092850688  2021-10-21T02:16:06.000Z
# 98  1451009358087733251  2021-10-21T02:16:04.000Z
# 99  1451009343198015490  2021-10-21T02:16:00.000Z
#
#                                                  text lang  \
# 0   @kinky_horror Is it just me or did Michael Mye...   en
# 1   RT @AnisulGFX: "We have to run, he's outside w...   en
# 2   RT @halloweenmovie: A series of encounters bet...   en
# 3   RT @SourceHalloween: The shape with blood on h...   en
# 4   RT @GeekVibesNews: Enter for a chance to win a...   en
# ..                                                ...  ...
# 95  Michael has been shot, stabbed, hung, burned, ...   en
# 96  RT @torishimaru: チャッキーとマイケル・マイヤーズが奇跡の対面果たすCMがア...   ja
# 97  RT @halloweenmovie: A series of encounters bet...   en
# 98  RT @halloweenmovie: A series of encounters bet...   en
# 99  RT @halloweenmovie: A series of encounters bet...   en
#
#                   name        username
# 0               Dakota    KodaFlixster
# 1                jay 🕷   yourightvinyl
# 2           Lisbethh .        lovoxxli
# 3   The Horror Returns  horror_returns
# 4    kesetaraan genjer      diupayakan
# ..                 ...             ...
# 95                 NaN             NaN
# 96                 NaN             NaN
# 97                 NaN             NaN
# 98                 NaN             NaN
# 99                 NaN             NaN
#
# [100 rows x 8 columns]

# %%
my_df.to_csv(r'/Users/travis/DEMT2021/TwitterReport.csv')

# %%
url_2 = url_expansions + '&next_token={}'.format(response_2_dict['meta']['next_token'])

# %%
response_2_dict = requests.request("GET", url_2, headers = header)

# %%
response_2_dict = json.loads(response_2.text)

# %%
user_info2 = pd.DataFrame(response_2_dict['includes']['users'])

# %%
my_df2 = pd.DataFrame(response_2_dict['data'])

# %%
my_df2['name'] = user_info2['name']
my_df2['username'] = user_info2['username']
my_df2
# Out:
#                                                  text  \
# 0   @kinky_horror Is it just me or did Michael Mye...
# 1   RT @AnisulGFX: "We have to run, he's outside w...
# 2   RT @halloweenmovie: A series of encounters bet...
# 3   RT @SourceHalloween: The shape with blood on h...
# 4   RT @GeekVibesNews: Enter for a chance to win a...
# ..                                                ...
# 95  Michael has been shot, stabbed, hung, burned, ...
# 96  RT @torishimaru: チャッキーとマイケル・マイヤーズが奇跡の対面果たすCMがア...
# 97  RT @halloweenmovie: A series of encounters bet...
# 98  RT @halloweenmovie: A series of encounters bet...
# 99  RT @halloweenmovie: A series of encounters bet...
#
#                   created_at            author_id lang  \
# 0   2021-10-21T02:33:57.000Z            196348989   en
# 1   2021-10-21T02:33:50.000Z  1421261552422895618   en
# 2   2021-10-21T02:33:50.000Z  1294531407352651777   en
# 3   2021-10-21T02:33:48.000Z  1448328941270454287   en
# 4   2021-10-21T02:33:46.000Z  1090776054506053632   en
# ..                       ...                  ...  ...
# 95  2021-10-21T02:16:34.000Z           1021502280   en
# 96  2021-10-21T02:16:19.000Z  1150423273546502144   ja
# 97  2021-10-21T02:16:06.000Z            441134548   en
# 98  2021-10-21T02:16:04.000Z  1376283615986847748   en
# 99  2021-10-21T02:16:00.000Z  1249826534501896193   en
#
#                                        public_metrics                   id  \
# 0   {'retweet_count': 0, 'reply_count': 0, 'like_c...  1451013861532971017
# 1   {'retweet_count': 4, 'reply_count': 0, 'like_c...  1451013830763597827
# 2   {'retweet_count': 213, 'reply_count': 0, 'like...  1451013830432149504
# 3   {'retweet_count': 38, 'reply_count': 0, 'like_...  1451013824560173056
# 4   {'retweet_count': 153, 'reply_count': 0, 'like...  1451013813365624832
# ..                                                ...                  ...
# 95  {'retweet_count': 0, 'reply_count': 2, 'like_c...  1451009486538293250
# 96  {'retweet_count': 143, 'reply_count': 0, 'like...  1451009421929115653
# 97  {'retweet_count': 213, 'reply_count': 0, 'like...  1451009367092850688
# 98  {'retweet_count': 213, 'reply_count': 0, 'like...  1451009358087733251
# 99  {'retweet_count': 213, 'reply_count': 0, 'like...  1451009343198015490
#
#                                name      username
# 0                     Lauri Mueller   LauriLinnea
# 1   Follow @KasimAkr | Read pinned!  KasimAkrBot1
# 2                                 b  inlovewghost
# 3                        Th3rd3y369    th3rd3y369
# 4                          Jason L.      Jlee7477
# ..                              ...           ...
# 95                              NaN           NaN
# 96                              NaN           NaN
# 97                              NaN           NaN
# 98                              NaN           NaN
# 99                              NaN           NaN
#
# [100 rows x 8 columns]

# %%
my_df2.to_csv(r'/Users/travis/DEMT2021/TwitterReport2.csv')

# %%
url_3 = url_expansions + '&next_token={}'.format(response_2_dict['meta']['next_token'])

# %%
response_3 = requests.request("GET", url_3, headers = header)

# %%
response_3_dict = json.loads(response_3.text)

# %%
user_info3 = pd.DataFrame(response_3_dict['includes']['users'])

# %%
my_df3 = pd.DataFrame(response_3_dict['data'])

# %%
my_df3['name'] = user_info3['name']
my_df3['username'] = user_info3['username']
my_df3
# Out:
#                                        public_metrics  \
# 0   {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 1   {'retweet_count': 239, 'reply_count': 0, 'like...
# 2   {'retweet_count': 239, 'reply_count': 0, 'like...
# 3   {'retweet_count': 239, 'reply_count': 0, 'like...
# 4   {'retweet_count': 226, 'reply_count': 0, 'like...
# ..                                                ...
# 95  {'retweet_count': 1, 'reply_count': 0, 'like_c...
# 96  {'retweet_count': 239, 'reply_count': 0, 'like...
# 97  {'retweet_count': 239, 'reply_count': 0, 'like...
# 98  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 99  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                   created_at lang            author_id  \
# 0   2021-10-21T02:15:54.000Z   en             35147084
# 1   2021-10-21T02:15:50.000Z   en  1291151002905739264
# 2   2021-10-21T02:15:40.000Z   en   994262360117293057
# 3   2021-10-21T02:15:38.000Z   en  1171660435608805381
# 4   2021-10-21T02:15:32.000Z   en  1219011688483246082
# ..                       ...  ...                  ...
# 95  2021-10-21T02:03:52.000Z   en  1251749775927439360
# 96  2021-10-21T02:03:52.000Z   en  1365058703326650377
# 97  2021-10-21T02:03:47.000Z   en             84533678
# 98  2021-10-21T02:03:43.000Z   en   954934012405014528
# 99  2021-10-21T02:03:41.000Z   en           1340523456
#
#                                                  text                   id  \
# 0   MAIL CALL! Thank you @halloweenmovie for this ...  1451009316899725319
# 1   RT @halloweenmovie: A series of encounters bet...  1451009302379040770
# 2   RT @halloweenmovie: A series of encounters bet...  1451009259202830349
# 3   RT @halloweenmovie: A series of encounters bet...  1451009249719508994
# 4   RT @DiscussingFilm: To celebrate the release o...  1451009225338114052
# ..                                                ...                  ...
# 95  Join your favorite #FleshWoundFiends (includin...  1451006291460038661
# 96  RT @halloweenmovie: A series of encounters bet...  1451006288138317830
# 97  RT @halloweenmovie: A series of encounters bet...  1451006269997740041
# 98  🤣🤣🤣 You can't make this shit up. #HalloweenKil...  1451006251891109889
# 99  @HeavenlysDiary_ Look at that scary mother fuc...  1451006243427045380
#
#                                        name         username
# 0   KUYA P aka Patrick Michael Strange 🇵🇭🇺🇸   TheLegendKuyaP
# 1                                    Sean ☆    AETHERGHOUL__
# 2                                    kenzie  Fuckinmoviesbro
# 3       Horror Nights MX (NOCHES DE HORROR)  HorrorNights_MX
# 4                                       ike          ike_300
# ..                                      ...              ...
# 95                      Her Spooky Man Matt    TwiztidWriter
# 96                                      NaN              NaN
# 97                                      NaN              NaN
# 98                                      NaN              NaN
# 99                                      NaN              NaN
#
# [100 rows x 8 columns]

# %%
my_df3.to_csv(r'/Users/travis/DEMT2021/TwitterReport3.csv')

# %% [markdown]
# # New movie hype Report

# %% [markdown]
# The Question I came up with for this project is what is the general consensus and hype around new movies coming out. I chose the movie Halloween Kills. I wanted to see what people were taking about this movie as halloween is a very popular franchise. The data that I pulled is helping me see what people are talking about for the specific movie that I chose to do. The code that I used helped pull all the metrics and information I needed to answer the question of The hype surrounding new movies coming out. Overall out of the data I pulled many people were happy with the movie, now a lot of data is retweets of multiple things, as well as giveaways. There was some sort of problem at the end of the data pulled that peoples names would come up as NaN. even though the tweet has everything that was needed, their username would not show up and it happened for all 3 data sets.
# This project was started by reading in my unique bearer tokens and converting it to something that this could read.
# Next using the twitter api to pull data and tweets that people made.
# after grabbing data I put it into a dataframe that could be read and then saved them.
# The biggest challenge for this data is the amount of giveaways and such that clog up this data.
